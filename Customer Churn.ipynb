# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("D:\Intellipaat\Python\Capstone Project\Capstone-project-2\Dataset\Dataset\customer_churn.csv")

# %%
dataset.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
customer_5=dataset.iloc[:,4]

# %%
customer_5.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %%
customer_15= dataset.iloc[:,14]
customer_15.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: StreamingMovies, dtype: object

# %%
senior_male_electronic=dataset[(dataset['gender']=='Male') &(dataset['SeniorCitizen']==1) & (dataset['PaymentMethod']=='Electronic check')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
customer_total_tenure= dataset[(dataset['tenure']>70) | (dataset['MonthlyCharges']>100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
two_mail_yes= dataset[(dataset['Contract']=='Two year')&(dataset['PaymentMethod']=='Mailed check')&(dataset['Churn']=='Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
customer_333=dataset.sample(n=333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 924   4824-GUCBY  Female              1      No         No      22
# 813   3551-GAEGL    Male              0     Yes        Yes      34
# 929   8812-ZRHFP  Female              0     Yes        Yes      30
# 3     7795-CFOCW    Male              0      No         No      45
# 1044  3354-OADJP  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 3246  8806-EAGWC    Male              0      No         No       3
# 5277  0345-HKJVM  Female              0      No         No       6
# 2088  6784-XYJAE  Female              0      No         No      36
# 305   1248-DYXUB    Male              0     Yes        Yes      52
# 5515  2892-GESUL  Female              0     Yes        Yes      18
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 924           Yes                No     Fiber optic                  Yes  ...
# ...

# %%
dataset['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
plt.bar(dataset['InternetService'].value_counts().keys().tolist(), dataset['InternetService'].value_counts().tolist(), color='orange')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of categories')
plt.title('Distribution of Internet Service')
# Out:
# Text(0.5, 1.0, 'Distribution of Internet Service')

# %%
plt.hist(dataset['tenure'], bins=30, color='green')
plt.title('Distribution of tenure')
# Out:
# Text(0.5, 1.0, 'Distribution of tenure')

# %%
plt.scatter(x=dataset['tenure'], y=dataset['MonthlyCharges'], color='brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customers')
plt.title('Tenure vs Monthly Charges')
# Out:
# Text(0.5, 1.0, 'Tenure vs Monthly Charges')

# %%
dataset.boxplot(column=['tenure'], by=['Contract'])
# Out:
# <AxesSubplot:title={'center':'tenure'}, xlabel='[Contract]'>

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x=dataset[['tenure']]
y=dataset[['MonthlyCharges']]

x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=0)

# %%
lr=LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_pred, y_test)
rmse=np.sqrt(mse)
rmse
# Out:
# 29.394584027273893

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
x=dataset[['MonthlyCharges']]
y=dataset[['Churn']]

x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.35, random_state=0)

# %%
log_r=LogisticRegression()
log_r.fit(x_train, y_train)
# Out:
# C:\Users\Tapas Gope\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred1=log_r.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
confusion_matrix(y_test,y_pred1),accuracy_score(y_test,y_pred1)
# Out:
# (array([[1815,    0],
#         [ 651,    0]], dtype=int64),
#  0.7360097323600974)

# %%
# Multiple Logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
x=dataset[['tenure','MonthlyCharges']]
y=dataset[['Churn']]

x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.20, random_state=0)

# %%
log_r=LogisticRegression()
log_r.fit(x_train, y_train)
# Out:
# C:\Users\Tapas Gope\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred2=log_r.predict(x_test)

# %%
confusion_matrix(y_test,y_pred2),accuracy_score(y_test,y_pred2)
# Out:
# (array([[934, 107],
#         [212, 156]], dtype=int64),
#  0.7735982966643009)

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

x=dataset[['tenure']]
y=dataset[['Churn']]

x_train,x_test, y_train, y_test= train_test_split(x,y, test_size=0.20, random_state=0)

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3= dtc.predict(x_test)

# %%
confusion_matrix(y_test, y_pred3), accuracy_score(y_test, y_pred3)
# Out:
# (array([[965,  76],
#         [281,  87]], dtype=int64),
#  0.7466288147622427)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
x=dataset[['tenure','MonthlyCharges']]
y=dataset[['Churn']]

x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.30, random_state=0)

# %%
rf=RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# C:\Users\Tapas Gope\AppData\Local\Temp\ipykernel_20612\1304056776.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train, y_train)
# RandomForestClassifier()

# %%
y_pred4=rf.predict(x_test)

# %%
confusion_matrix(y_test, y_pred4), accuracy_score(y_test, y_pred4)
# Out:
# (array([[1345,  215],
#         [ 328,  225]], dtype=int64),
#  0.7430194036914339)
